# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Vectorization
def vectorize(sequences, dimension=10000):
 results = np.zeros((len(sequences), dimension))
 for i, seq in enumerate(sequences):
  results[i, seq] = 1
 return results
x_train = vectorize(x_train)
x_test = vectorize(x_test)
y_train = np.asarray(y_train).astype("float32")
y_test = np.asarray(y_test).astype("float32")

# %%
# Model
model = keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10000,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train
model.fit(x_train, y_train, epochs=10, batch_size=512, validation_split=0.2)
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8023 - loss: 0.4948 - val_accuracy: 0.8814 - val_loss: 0.3328
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9113 - loss: 0.2518 - val_accuracy: 0.8938 - val_loss: 0.2794
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9378 - loss: 0.1828 - val_accuracy: 0.8914 - val_loss: 0.2757
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9549 - loss: 0.1414 - val_accuracy: 0.8904 - val_loss: 0.2889
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9654 - loss: 0.1137 - val_accuracy: 0.8868 - val_loss: 0.3118
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9722 - loss: 0.0934 - val_accuracy: 0.8806 - val_loss: 0.3428
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9801 - loss: 0.0751 - val_accuracy: 0.8800 - val_loss: 0.3794
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9861 - loss: 0.0601 - val_accuracy: 0.8774 - val_loss: 0.4131
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9879 - loss: 0.0522 - val_accuracy: 0.8744 - val_loss: 0.4519
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9919 - loss: 0.0408 - val_accuracy: 0.8718 - val_loss: 0.4958

# %%
# Evaluate
loss, acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8581 - loss: 0.5322
# Test Accuracy: 0.8580800294876099

# %%
# Predict
pred = model.predict(x_test[:5])
print("Predictions:", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predictions: [[0.07373105]
#  [0.9999943 ]
#  [0.04289415]
#  [0.9405406 ]
#  [0.98771024]]
